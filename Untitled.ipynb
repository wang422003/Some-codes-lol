# %%
import glob
import cv2
import numpy as np

my_images = sorted(glob.glob('./test_images/*.jpg'))
my_labels = np.array([12, 38, 5, 30, 34])

# %%
def plot_figures(figures, nrows = 1, ncols=1, labels=None):
    fig, axs = plt.subplots(ncols=ncols, nrows=nrows, figsize=(12, 14))
    axs = axs.ravel()
    for index, title in zip(range(len(figures)), figures):
        axs[index].imshow(figures[title], plt.gray())
        if(labels != None):
            axs[index].set_title(labels[index])
        else:
            axs[index].set_title(title)
            
        axs[index].set_axis_off()
        
    plt.tight_layout()

# %%
def image_show(filename):
    plt.figure()
    plt.imshow(filename)

# %%
import matplotlib.pyplot as plt
figures = []
labels = {}
my_signs = []
index = 0
for my_image in my_images:
    img = cv2.cvtColor(cv2.imread(my_image), cv2.COLOR_BGR2RGB)
    my_signs.append(img)
    image_show(img)

# %%
print(my_signs[0])
print(type(my_signs[0]))
my_signs[0].shape
# Out:
# [[[170 173 188]
#   [168 171 186]
#   [164 167 182]
#   ...
#   [116 132 165]
#   [113 129 162]
#   [114 130 163]]
#
#  [[165 171 187]
#   [164 170 186]
#   [161 166 185]
#   ...
#   [106 127 158]
#   [104 125 156]
#   [102 125 156]]
#
#  [[160 168 187]
#   [160 168 187]
#   [155 166 186]
#   ...
#   [103 130 160]
#   [101 128 158]
#   [102 129 159]]
#
#  ...
#
#  [[ 66  68  65]
#   [ 69  71  68]
#   [ 68  70  65]
#   ...
#   [ 98  92  42]
#   [ 89  86  35]
#   [ 85  83  32]]
#
#  [[ 69  69  67]
#   [ 71  72  67]
#   [ 68  69  63]
#   ...
#   [102  90  38]
#   [ 97  87  34]
#   [ 92  87  32]]
#
#  [[ 63  63  61]
#   [ 65  67  64]
#   [ 67  69  64]
#   ...
#   [104  93  39]
#   [100  93  38]
#   [101  96  40]]]
# <class 'numpy.ndarray'>
# (199, 300, 3)

# %%
#my_signs = np.array(my_signs)

#for my_image in my_signs:
#    figures.append (my_image)
 #   index += 1
#figures = np.array(figures)
my_signs[0] = np.sum(my_signs[0]/3, axis=3, keepdims=True)
image_show(my_signs[0])
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-48-b4d8c4f763a6> in <module>()
#       5  #   index += 1
#       6 #figures = np.array(figures)
# ----> 7 my_signs[0] = np.sum(my_signs[0]/3, axis=3, keepdims=True)
#       8 image_show(my_signs[0])
#
# H:\For_New_Trends\Python\lib\site-packages\numpy\core\fromnumeric.py in sum(a, axis, dtype, out, keepdims)
#    1880             return sum(axis=axis, dtype=dtype, out=out, **kwargs)
#    1881     return _methods._sum(a, axis=axis, dtype=dtype,
# -> 1882                          out=out, **kwargs)
#    1883
#    1884
#
# H:\For_New_Trends\Python\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
# ...
